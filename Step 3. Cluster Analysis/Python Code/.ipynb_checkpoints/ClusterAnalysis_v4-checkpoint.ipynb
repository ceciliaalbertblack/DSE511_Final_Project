# %% [markdown]
# ## DSE 511 Final Project Cluster Analysis in Python
# #### Jared Schlak
# #### 2025-11-14

# %%
#Load the necessary libraries/packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from kmodes.kmodes import KModes
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
#Import Data from Step 1. Data Cleaning

# 1. Load the CSV file
clean_df = pd.read_csv('../../Step 1. Data Cleaning/Python code/outbreak_clean_v2.csv')

print(clean_df.head())
print(clean_df.info())
print(clean_df.describe())
# Out:
#    year  month        date  season       state state_abbr primary_mode  \
# 0  1971      2  1971-02-01  Winter  California         CA        Water
# 1  1971      6  1971-06-01  Summer    Arkansas         AR        Water
# 2  1971      6  1971-06-01  Summer    Missouri         MO        Water
# 3  1971      6  1971-06-01  Summer     Alabama         AL        Water
# 4  1971      6  1971-06-01  Summer     Vermont         VT        Water
#
#                     setting     etiology etiology_grouped  ... illnesses_std  \
# 0                Restaurant       Copper            Other  ...     -0.019976
# 1                     Store  Hepatitis A        Hepatitis  ...      0.041387
# 2  Subdivision/Neighborhood      Unknown          Unknown  ...     -0.019976
# 3                   Unknown     Selenium            Other  ...     -0.019336
# 4    Community/municipality      Unknown          Unknown  ...     -0.019336
#
#   hospitalizations_std deaths_std hosp_per_ill death_per_ill  \
# 0            -0.184611  -0.091011          0.0           0.0
# 1            -0.184611  -0.091011          0.0           0.0
# 2            -0.184611  -0.091011          0.0           0.0
# 3            -0.184611  -0.091011          0.0           0.0
# 4            -0.184611  -0.091011          0.0           0.0
#
#   food_vehicle_missing water_exposure_missing  is_food_related  \
# 0              Missing                Present                0
# 1              Missing                Present                0
# 2              Missing                Present                0
# 3              Missing                Present                0
# 4              Missing                Present                0
#
#    is_water_related  is_animal_related
# 0                 1                  0
# 1                 1                  0
# 2                 1                  0
# 3                 1                  0
# 4                 1                  0
#
# [5 rows x 30 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66706 entries, 0 to 66705
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    66706 non-null  int64
#  1   month                   66706 non-null  int64
#  2   date                    66706 non-null  object
#  3   season                  66706 non-null  object
#  4   state                   66706 non-null  object
#  5   state_abbr              66706 non-null  object
#  6   primary_mode            66706 non-null  object
#  7   setting                 66706 non-null  object
#  8   etiology                66706 non-null  object
#  9   etiology_grouped        66706 non-null  object
#  10  ifsac_category          66706 non-null  object
#  11  food_vehicle            66706 non-null  object
#  12  water_exposure          66706 non-null  object
#  13  water_type              66706 non-null  object
#  14  water_type_group        66706 non-null  object
#  15  animal_type             66706 non-null  object
#  16  animal_group            66706 non-null  object
#  17  illnesses               66706 non-null  float64
#  18  hospitalizations        66706 non-null  float64
#  19  deaths                  66706 non-null  float64
#  20  illnesses_std           66706 non-null  float64
#  21  hospitalizations_std    66706 non-null  float64
#  22  deaths_std              66706 non-null  float64
#  23  hosp_per_ill            66706 non-null  float64
#  24  death_per_ill           66706 non-null  float64
#  25  food_vehicle_missing    66706 non-null  object
#  26  water_exposure_missing  66706 non-null  object
#  27  is_food_related         66706 non-null  int64
#  28  is_water_related        66706 non-null  int64
#  29  is_animal_related       66706 non-null  int64
# dtypes: float64(8), int64(5), object(17)
# memory usage: 15.3+ MB
# None
#                year         month      illnesses  hospitalizations  \
# count  66706.000000  66706.000000   66706.000000      66706.000000
# mean    2012.698363      5.691737      33.251477          0.718856
# std        7.545193      3.736758    1564.495083          3.893926
# min     1971.000000      1.000000       2.000000          0.000000
# 25%     2009.000000      2.000000       5.000000          0.000000
# 50%     2014.000000      5.000000      14.000000          0.000000
# 75%     2018.000000      9.000000      30.000000          0.000000
# max     2023.000000     12.000000  403000.000000        308.000000
#
#              deaths  illnesses_std  hospitalizations_std    deaths_std  \
# count  66706.000000   6.670600e+04          6.670600e+04  6.670600e+04
# mean       0.037253   3.493809e-17          6.604151e-17  2.854698e-17
# std        0.409329   1.000007e+00          1.000007e+00  1.000007e+00
# min        0.000000  -1.997559e-02         -1.846109e-01 -9.101070e-02
# 25%        0.000000  -1.805802e-02         -1.846109e-01 -9.101070e-02
# 50%        0.000000  -1.230533e-02         -1.846109e-01 -9.101070e-02
# 75%        0.000000  -2.078307e-03         -1.846109e-01 -9.101070e-02
# max       50.000000   2.575718e+02          7.891352e+01  1.220611e+02
#
#        hosp_per_ill  death_per_ill  is_food_related  is_water_related  \
# count  66706.000000   66706.000000     66706.000000      66706.000000
# mean       0.053834       0.003056         0.370686          0.046488
# std        0.166138       0.034310         0.482992          0.210540
# min        0.000000       0.000000         0.000000          0.000000
# 25%        0.000000       0.000000         0.000000          0.000000
# 50%        0.000000       0.000000         0.000000          0.000000
# 75%        0.000000       0.000000         1.000000          0.000000
# max        2.333333       1.000000         1.000000          1.000000
#
#        is_animal_related
# count       66706.000000
# mean            0.009819
# std             0.098605
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.000000
# max             1.000000
